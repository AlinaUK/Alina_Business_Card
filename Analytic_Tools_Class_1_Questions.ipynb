# %% [markdown]
# <a href="https://colab.research.google.com/github/AlinaUK/Alina_Business_Card/blob/main/Analytic_Tools_Class_1_Questions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to Class 1 exercises.
#
# **Answer the following questions using Python programming language and the class slides**

# %% [markdown]
# # Task 1: Explore basic statistics with Python

# %% [markdown]
# **Question 1.1**: Let's run some simple statistics.
# Let's find the mean, the variance and the standard deviation for the following case study.
#
# You and your friends have just measured your heights (in millimeters). Let's assume the following data:
# * John 170
# * Mary 150
# * Tom 185
# * Jenny 170
# * Anna 180
#
# Our task is to visualise the data, and caluclate the mean and the standard deviation.
#
# Firstly, let's plot the data. Study and run the following script.

# %%
import matplotlib.pyplot as plt

x = ['John', 'Mary', 'Tom', 'Jenny', 'Anna']
y = [170, 150, 185, 170, 180]

# Plot the data
plt.scatter(x, y, label='heights')
plt.ylim(0, 220)

# Add a legend
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# **Question 1.2**: Let us draw an average line in the scatterplot, by that we can see the distance of each point from the mean. What do you observe?
#
# Run the following code to visualise the data.
#
#
# > Do not worry about the **NumPy** package, we will discuss it in the next class.

# %%
import matplotlib.pyplot as plt
import random
import numpy as np

# Create some random data
x = ['John', 'Mary', 'Tom', 'Jenny', 'Anna']
y = [170, 150, 185, 170, 180]

# Calculate the  average of the data
# This is an alternative way using the numpy package
# that we will discuss in the next class...
y_mean = [np.mean(y)]*len(x)

fig,ax = plt.subplots()

# Plot the data
data_line = ax.plot(x,y, label='Data', marker='o')

# Plot the average line
mean_line = ax.plot(x,y_mean, label='Mean', linestyle='--')

# Make a legend
legend = ax.legend(loc='upper right')

plt.show()

# It looks that John and Jenny are close to the mean.
# Mary looks far from the mean...

# %% [markdown]
# **Question 1.3**: Let us change the scale of the y-axis.
#
# Study and run the following code.
# What do you observe?

# %%
# This is the same code as Question 1.2

import matplotlib.pyplot as plt
import random
import numpy as np

# Create some random data
x = ['John', 'Mary', 'Tom', 'Jenny', 'Anna']
y = [170, 150, 185, 170, 180]
y_mean = [np.mean(y)]*len(x)
fig,ax = plt.subplots()
data_line = ax.plot(x,y, label='Data', marker='o')
mean_line = ax.plot(x,y_mean, label='Mean', linestyle='--')
legend = ax.legend(loc='upper right')

# The ylim() function in pyplot module of matplotlib library is used
# to get or set the y-limits of the y-axes.

plt.ylim(0, 220)

plt.show()

# Data looks less dispersed!
# We need something (a metric) to help us decide what is the
# average amount of variability in our data set.

# %% [markdown]
# **Question 2:** Let's find the mean of our data. Study and run the following.
#
# > Make sure you understand how the following code works.

# %%
# To calculate the mean:
# mean = (170 + 150 + 185 + 170 + 180) / 5

mysum = 0
mycount = 0
for i in y:
  mysum += i # Increate the sum by value (i)
  mycount += 1 # Increate the counter by 1

mean = mysum / mycount
print(mean)
# Out:
# 171.0

# %% [markdown]
# **Question 3.1:** Let's calculate the variance and the standard deviation. Study and run the following.
#
# > This is a challenging task, so take your time to study it.

# %%
import math

sumdif = 0
for height in y:
  # The following calculates the difference of each height from the mean
  # Then, we square this difference
  # Finally we sum all the square differences

  sumdif += (height-mean)**2

# The variance is the sum of squared differences divided by the number of elements
variance = sumdif / mycount

# The standard deviation is the square root of the variance
std = math.sqrt(variance)

# Let's print everything
print("Mean:", mean)
print("Variance:", variance)
print("Standard deviation:", std)
# Out:
# Mean: 171.0
# Variance: 144.0
# Standard deviation: 12.0

# %% [markdown]
# **Question 3.2:** Let's plot the difference (distance) of each point from the mean, to do this we will create a list of distances of a point from the mean.
#
# In visualisation, showing these distances effectively can make a plot convey much more complete information.
#
#
# Study and run the following, what do you observe?

# %%
import matplotlib.pyplot as plt
import numpy as np
import math

x = np.array(['John', 'Mary', 'Tom', 'Jenny', 'Anna'])
y = np.array([170, 150, 185, 170, 180])

# difference between each y point and the mean
distance_from_mean = np.abs([170-mean, 150-mean, 185-mean, 170-mean, 180-mean])

plt.errorbar(x, y, distance_from_mean, linestyle='None', marker='^')
plt.ylim(110, 220)

plt.show()

# It seems that John and Jenny are high precision values.
# Mary is the value with the highest error, means that
# her height is far from the mean.

# %% [markdown]
# **Question 4:** Caluclate the standard deviation of the following dataset that includes the weights of five dogs.
#
# * **mydata = {'Max':15, 'Buddy':25, 'Matilda':8, 'Paco':12, 'Pablo':30}**
#
# Implement scripts for the following tasks:
#
# 1. Create a scatterplot for the dataset.
# 2. Calculate the mean and print it.
# 3. Calculate the standard deviation and print it.
#
# To make sure your math calculations are correct, use the following standard deviation calculator (Standard Deviation of a population).
#
# https://www.calculator.net/standard-deviation-calculator.html
#
# > This is a challenging task, so take your time.

# %%
mydata = {'Max':15, 'Buddy':25, 'Matilda':8, 'Paco':12, 'Pablo':30}

# 1. Provide the code to show a scatterplot here


# 2. Provide the code to calculate the mean here


# 3. Provide the code to calculate the standard deviation here

# %% [markdown]
# **Question 5:** Can you refactor the code of **Question 4** to create:
# * A function called **getCountMean** to return the **counter of the elements and the mean** as a tuple
# * A function that uses the **getCountMean** to caclulate the standard deviation, using the tuple
#
# > What does refactoring mean in coding?
# >
# > Code refactoring is defined as the process of restructuring computer code without changing or adding to its external behavior and functionality.
#
#
# > This is a challenging task to explore as a homework.

# %%
# Provide your solution here

# %% [markdown]
# ---

# %% [markdown]
# # Task 2: Working with Pandas

# %% [markdown]
# **Question 1:** Pandas is an open source Python library providing a selection of options to develop data analytics.
#
# Let us first create a new dataframe using the following dataset (a dictionary).
#
# data = {'City':['London', 'Athens', 'Paris', 'Rome'],
#         'Population':[8.982, 3.154, 2.1, 2.8]}
#
# Create a dataframe out of this data and print it.
# You are advised to study the slides.

# %%
# Provide your solution here

# %% [markdown]
# A **dataframe** is a 2-dimensional labeled data structure with columns of potentially different types. For more information refer to the guidelines available here: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.html

# %% [markdown]
# **Question 2:** Use the the following dictionary (called data) to create a dataframe and print only the column called **city** and **population**.

# %%
data = {'City':['London', 'Athens', 'Paris', 'Rome'],
        'Population':[8.982, 3.154, 2.1, 2.8],
        'Attraction':['Big Ben', 'Parthenon', 'Eiffel tower', 'Colosseum']}

# Provide your solution here
data = {'City':['London', 'Athens', 'Paris', 'Rome'],
        'Population':[8.982, 3.154, 2.1, 2.8],
        'Attraction':['Big Ben', 'Parthenon', 'Eiffel tower', 'Colosseum']}

# Provide your solution here

import pandas as pd

# Define a dictionary containing data
data = {'City':['London', 'Athens', 'Paris', 'Rome'],
        'Population':[8.982, 3.154, 2.1, 2.8],
        'Attraction':['Big Ben', 'Parthenon', 'Eiffel tower', 'Colosseum']}

# Convert the dictionary into a DataFrame
df = pd.DataFrame(data)

# select the columns
print(df[['City', 'Population']])
# Out:
#      City  Population
# 0  London       8.982
# 1  Athens       3.154
# 2   Paris       2.100
# 3    Rome       2.800

# %% [markdown]
# **Question 3:** Upload the file called *Biostats2.csv* and read it using the **read_csv*( pandas library. Print the data and have a look at the values.
#
# Did you find any problems?

# %%
# Provide your solution here
import pandas as pd

df = pd.read_csv('/content/Biostats2 (1).csv')

print(df)
# Out:
#     Name Sex   Age  Height(in)  Weight(lbs)
# 0   Alex   M  41.0        74.0        170.0
# 1   Bert   M  42.0        68.0        166.0
# 2   Dave   M  32.0        70.0        155.0
# 3   Dave   M   NaN        72.0        167.0
# 4   Elly   F  30.0        66.0        124.0
# 5   Fran   F  33.0        66.0        115.0
# 6   Gwen   F  26.0        64.0        121.0
# 7   Hank   M   NaN        71.0          NaN
# 8   Luke   M  53.0        72.0        175.0
# 9   Jake   M  32.0        69.0        143.0
# 10  Kate   F  47.0        69.0        139.0
# 11  Luke   M   NaN        72.0        163.0
# 12  Myra   F  23.0         NaN         98.0
# 13  Neil   M  36.0        75.0        160.0
# 14  Omar   M  38.0        70.0        145.0
# 15  Page   F  31.0        67.0        135.0
# 16  Luke   M  29.0        71.0          NaN
# 17  Ruth   F  28.0        65.0        131.0

# %% [markdown]
# > There are a few **NaN** values in our dataset. These are cells that are empty and could potentially create problems to our further analysis.

# %% [markdown]
# **Question 4:** Query the dataset to print all the data for Name, Sex and Age.

# %%
# Provide your solution here


print(df[['Name', 'Sex', 'Age']])
# Out:
#     Name Sex   Age
# 0   Alex   M  41.0
# 1   Bert   M  42.0
# 2   Dave   M  32.0
# 3   Dave   M   NaN
# 4   Elly   F  30.0
# 5   Fran   F  33.0
# 6   Gwen   F  26.0
# 7   Hank   M   NaN
# 8   Luke   M  53.0
# 9   Jake   M  32.0
# 10  Kate   F  47.0
# 11  Luke   M   NaN
# 12  Myra   F  23.0
# 13  Neil   M  36.0
# 14  Omar   M  38.0
# 15  Page   F  31.0
# 16  Luke   M  29.0
# 17  Ruth   F  28.0

# %% [markdown]
# **Question 5:** Query the dataset to print the records for male employees.

# %%
# Provide your solution here
# Create a variable to identify rows where Sex is Male
male = df['Sex'] == "M"

# Select all cases where Sex is Male
males_df = df[male]

# Select all cases where Sex is Male and Age is less than 30
males_under_30 = df[male & (df['Age'] < 30)]

# Extract only 'Name' and 'Age' columns for males under 30
names_ages_males_under_30 = males_under_30[['Name', 'Age']]

print(names_ages_males_under_30)
# Out:
#     Name   Age
# 16  Luke  29.0

# %% [markdown]
# **Question 6:** Query the dataset to print the **names** and **ages** for male employees with Height less than 70 inches.

# %%
# Provide your solution here


male_height_condition = (df['Sex'] == "M") & (df['Height(in)'] < 70)  # Adjusted column name
print(df[male_height_condition])
# Out:
#    Name Sex   Age  Height(in)  Weight(lbs)
# 1  Bert   M  42.0        68.0        166.0
# 9  Jake   M  32.0        69.0        143.0

# %% [markdown]
# **Question 7:** Query the dataset to print the records for all employees called **Luke** or **Kate**.

# %%
# Provide your solution here

# Create variable with TRUE if Name is Luke
luke = df['Name'] == "Luke"

# Create variable with TRUE if Name is Kate
kate = df['Name'] == "Kate"

# Select all cases where Name is either Luke or Kate
filtered_df = df[luke | kate]

# Print the filtered records
print(filtered_df)
# Out:
#     Name Sex   Age  Height(in)  Weight(lbs)
# 8   Luke   M  53.0        72.0        175.0
# 10  Kate   F  47.0        69.0        139.0
# 11  Luke   M   NaN        72.0        163.0
# 16  Luke   M  29.0        71.0          NaN

# %% [markdown]
# In dataframes we can use **&** for AND and **|** for OR.

# %% [markdown]
# **Question 8:** Describe the dataframe using the *describe* method.

# %%
# Provide your solution here
df.describe()
# Out:
#              Age  Height(in)  Weight(lbs)
# count  15.000000   17.000000    16.000000
# mean   34.733333   69.470588   144.187500
# std     8.171961    3.144790    22.435742
# min    23.000000   64.000000    98.000000
# 25%    29.500000   67.000000   129.250000
# 50%    32.000000   70.000000   144.000000
# 75%    39.500000   72.000000   163.750000
# max    53.000000   75.000000   175.000000

# %% [markdown]
# > We can extract useful statistics such as the oldest employee is 53, the youngest is 23, the average age is 34.73. Similar statistics are also generated automatically for the rest of the integer-based columns (height and weight).

# %% [markdown]
# **Question 9:** We can use the *loc* method to extract data, revise the slides and extract all the female employees using the *loc* method.

# %%
# Provide your solution here
df.loc[df['Sex'] == 'F']
# Out:
#     Name Sex   Age  Height(in)  Weight(lbs)
# 4   Elly   F  30.0        66.0        124.0
# 5   Fran   F  33.0        66.0        115.0
# 6   Gwen   F  26.0        64.0        121.0
# 10  Kate   F  47.0        69.0        139.0
# 12  Myra   F  23.0         NaN         98.0
# 15  Page   F  31.0        67.0        135.0
# 17  Ruth   F  28.0        65.0        131.0

# %% [markdown]
# **Question 10:** Query the dataset to **count** the number of **male** and **female** employees. Print the results. You can use the *groupby* method as seend in class.

# %%
# Provide your solution here
# Group the dataset by 'Sex' and count the number of employees in each group
sex_counts = df.groupby('Sex').size()

# Print the results
print(sex_counts)
# Out:
# Sex
# F     7
# M    11
# dtype: int64

# %% [markdown]
# **Question 11:** Query the dataset to **count** how many empty values are in the **Age** column.

# %%
# Provide your solution here
age_counts= df['Age'].isna().sum()
print(age_counts)
# Out:
# 3

# %% [markdown]
# **Question 12:** Study and run the following code. Add your comments to explain the script functionality.

# %%
# The following script will extract all the employees with age less than 30 years old
print(df.loc[df.Age<30])

# The following script will extract the rows with index number 0, 2 and 4
print(df.iloc[[0,2,4]])
# Out:
#     Name Sex   Age  Height(in)  Weight(lbs)
# 6   Gwen   F  26.0        64.0        121.0
# 12  Myra   F  23.0         NaN         98.0
# 16  Luke   M  29.0        71.0          NaN
# 17  Ruth   F  28.0        65.0        131.0
#    Name Sex   Age  Height(in)  Weight(lbs)
# 0  Alex   M  41.0        74.0        170.0
# 2  Dave   M  32.0        70.0        155.0
# 4  Elly   F  30.0        66.0        124.0

# %% [markdown]
# **Question 13:** Query the dataset to **count** how many times a name of an employee exist in the **Age** column of the dataset. Filter your results by **Name** and **Age**.

# %%
# Provide your solution here

df.groupby('Name').count().filter(['Name','Age'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-8f1948e98b48> in <cell line: 3>()
#       1 # Provide your solution here
#       2
# ----> 3 df.groupby('Name').count().filter(['Name','Age'])
#
# NameError: name 'df' is not defined

# %% [markdown]
# Hank exists in my dataset but this name has a missing age.

# %% [markdown]
# **Question 14:** Run the following code to create a new dataframe.

# %%
# Let us use the following dictionary from student data

import pandas as pd

raw_data = {'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'],
        'last_name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze'],
        'age': [42, 52, 36, 24, 73],
        'preTestScore': [4, 24, 31, 2, 3],
        'postTestScore': [25, 94, 57, 62, 70]}

# Create a new dataframe and print it
df = pd.DataFrame(raw_data)
print(df)
# Out:
#   first_name last_name  age  preTestScore  postTestScore
# 0      Jason    Miller   42             4             25
# 1      Molly  Jacobson   52            24             94
# 2       Tina       Ali   36            31             57
# 3       Jake    Milner   24             2             62
# 4        Amy     Cooze   73             3             70

# %% [markdown]
# **Question 15:** Calculate the mean of the preTestScore.

# %%
# Provide your solution here

mean_preTestScore = df['preTestScore'].mean()

mean_preTestScore
# Out:
# 12.8

# %% [markdown]
# **Question 16:** Calculate the **max**imum value and then the **min**imum value of the preTestScore. Print both values.

# %%
# Provide your solution here

max_preTestScore = df['preTestScore'].max()
min_preTestScore = df['preTestScore'].min()

print(max_preTestScore)
print(min_preTestScore)
# Out:
# 31
# 2

# %% [markdown]
# **Question 17:** Query the dataset to find the students with an age between 50 and 55 years old. You are adviced to use the **loc** method. Please note, in order to add more than one criterion you will need to use parenthesis to group your boolean queries to remove ambiguity.
#
#
# > This is a challenging task, so take your time.

# %%
# Provide your solution here
df.loc[(df['age'] >= 50) & (df['age'] <= 55)]
# Out:
#   first_name last_name  age  preTestScore  postTestScore
# 1      Molly  Jacobson   52            24             94

# %% [markdown]
# **Question 18:** Create a function to query the dataset to search for a student using her/his last name. The function should return back the row from the dataframe. Make sure you prompt the user to input for a **name** to search.
#
#
# > This is a challenging task, so take your time.

# %%
# Provide your solution here


def search(name):
  result = df.loc[(df['last_name'] == name)]

  if result.empty:
    print("Sorry, there is nobody with this last name!")
  else: return result

name_to_search = input("Enter a last name to search: ")
search(name_to_search)
# Out:
# Enter a last name to search: miller
# Sorry, there is nobody with this last name!
