# %% [markdown]
# <a href="https://colab.research.google.com/github/AlinaUK/Alina_Business_Card/blob/main/Analytic_Tools_Class_8_Questions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to Class 8 exercises.
#
# **Answer the following questions using Python programming language and class slides.**

# %% [markdown]
# # **Part 1: Running common NLP tasks**

# %% [markdown]
# **Question 1:** Provide a Python script to count the number of characters of the following text.

# %%
text = """Two households, both alike in dignity,
          In fair Verona, where we lay our scene, From ancient
          grudge break to new mutiny, Where civil
          blood makes civil hands unclean."""

# Provide your solution here
count = 0
for char in text:
  count+=1
print(count)
# Out:
# 194

# %% [markdown]
# **Question 2:** Consider the following text.
#
# Calculate the word frequencies. Creat a script to use a dictionary and count how many times a word appears in the text.
# The words will be the keys, and the counters will be the values.

# %%
text = """London has been called the world's most powerful,
          most desirable, most influential,
          most visited, most expensive,
          sustainable, most investment-friendly,
          and most-popular-for-work city."""

# Provide your solution here
word_freq  = dict()
for word in text.split():
  if word not in word_freq:
    word_freq[word] = 1
else:
      word_freq[word] += 1
      print(word_freq)
# Out:
# {'London': 1, 'has': 1, 'been': 1, 'called': 1, 'the': 1, "world's": 1, 'most': 1, 'powerful,': 1, 'desirable,': 1, 'influential,': 1, 'visited,': 1, 'expensive,': 1, 'sustainable,': 1, 'investment-friendly,': 1, 'and': 1, 'most-popular-for-work': 1, 'city.': 2}

# %% [markdown]
# **Question 3:** Use the **word_tokenize** method to trasnform a text to a list of words.

# %%
import nltk

nltk.download('all')


# nltk.download('punkt')
# nltk.download('averaged_perceptron_tagger')

text = 'Analytic Tools for Data Science'

# Provide your solution here

tokens = nltk.word_tokenize(text)
tokens
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_eng.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_rus to
# ...

# %% [markdown]
# **Question 4:** Download the Guteneberg coprus.
#
# Print the list of books provided with the gutenber corpus.
#
# * The Project Gutenberg electronic text archive, which contains some 25,000 free electronic books, hosted at http://www.gutenberg.org/.

# %%
# Provide your solution here
import nltk
nltk.download('gutenberg')
nltk.corpus.gutenberg.fileids()
# Out:
# [nltk_data] Downloading package gutenberg to /root/nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %% [markdown]
# **Question 5:** What is the total number of words written in the **shakespeare-hamlet.txt** file?

# %%
# Provide your solution here
hamlet = nltk.corpus.gutenberg.words('shakespeare-hamlet.txt')
len(hamlet)
# Out:
# 37360

# %% [markdown]
# **Question 6:** Transform the hamlet text in an **NLTK Text** object. Print the **concordances** of the word *King** using the hamlet text.

# %%
# Provide your solution here
hamlet = nltk.Text(nltk.corpus.gutenberg.words('shakespeare-hamlet.txt'))
hamlet.concordance('King')
# Out:
# Displaying 25 of 172 matches:
# nfold your selfe Bar . Long liue the King Fran . Barnardo ? Bar . He Fran . Yo
# Barn . In the same figure , like the King that ' s dead Mar . Thou art a Schol
# oratio Barn . Lookes it not like the King ? Marke it Horatio Hora . Most like
# e owne eyes Mar . Is it not like the King ? Hor . As thou art to thy selfe , S
# least the whisper goes so : Our last King , Whose Image euen but now appear '
# , a Moity competent Was gaged by our King : which had return ' d To the Inheri
# unt . Scena Secunda . Enter Claudius King of Denmarke , Gertrude the Queene ,
# s Sister Ophelia , Lords Attendant . King . Though yet of Hamlet our deere Bro
# ersonall power To businesse with the King , more then the scope Of these dilat
# d all things , will we shew our duty King . We doubt it nothing , heartily far
# em to your gracious leaue and pardon King . Haue you your Fathers leaue ? What
# ...

# %% [markdown]
# **Question 7:** What is the total number of characters of the **shakespeare-hamlet.txt**?
#
# * Use the nltk.corpus.gutenberg method

# %%
# Provide your solution here
len(nltk.corpus.gutenberg.raw('shakespeare-hamlet.txt'))
# Out:
# 162881

# %% [markdown]
# **Question 8:** What is the total number of words of the **shakespeare-hamlet.txt**?

# %%
# Provide your solution here
len(nltk.corpus.gutenberg.words('shakespeare-hamlet.txt'))
# Out:
# 37360

# %% [markdown]
# **Question 9:** What is the total number of sentences of the **shakespeare-hamlet.txt**?

# %%
# Provide your solution here
len(nltk.corpus.gutenberg.sents('shakespeare-hamlet.txt'))
# Out:
# 3106

# %% [markdown]
# **Question 10:** The next scirpt downloads the **book** corpus and imports all the books.
#
# Run the next script.

# %%
import nltk
nltk.download('book')
from nltk.book import *
# Out:
# [nltk_data] Downloading collection 'book'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package brown to /root/nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package chat80 to /root/nltk_data...
# [nltk_data]    |   Package chat80 is already up-to-date!
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package conll2000 to /root/nltk_data...
# [nltk_data]    |   Package conll2000 is already up-to-date!
# [nltk_data]    | Downloading package conll2002 to /root/nltk_data...
# [nltk_data]    |   Package conll2002 is already up-to-date!
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     /root/nltk_data...
# ...

# %% [markdown]
# **Question 11:** What is text1 about? Run the following command.

# %%
text1

# Text 1 is the Moby Dick book
# Out:
# <Text: Moby Dick by Herman Melville 1851>

# %% [markdown]
# **Question 12:** Use the concordance method to examine the context of the word **feel** in the Moby Dick text.

# %%
# Provide your solution here
text1.concordance('feel')
# Out:
# Displaying 25 of 57 matches:
# hom one sometimes loves to sit , and feel poor - devilish , too ; and grow con
# ge as a passenger , did you yourself feel such a mystical vibration , when fir
# I could not help it , but I began to feel suspicious of this " dark complexion
#  my shirt sleeves . But beginning to feel very cold now , half undressed as I
# ngs of some unceasing grief , that I feel sure that here before me were assemb
# ows there ; Which none but they that feel can tell -- Oh , I was plunging to d
# w - like and boisterously grand ! We feel the floods surging over us ; we soun
# ht of sights to see ; yet I began to feel myself mysteriously drawn towards hi
# d , in the general consciousness you feel most delightfully and unmistakably w
# ing in bed . Because no man can ever feel his own identity aright except his e
# nt service indeed ! I suppose now ye feel considerable proud of having served
# ...

# %% [markdown]
# **Question 13:** Use the **similar** method to examine the similar context of the word **affection** in the Moby Dick text.

# %%
# Provide your solution here
text1.similar('affection')
# Out:
# world while whale tongue more devil lord sea days other man ship wind
# voyage captain same fishery air papers matter

# %% [markdown]
# **Question 14:** Print the collocations for text5 (chat text).

# %%
# Provide your solution here
text5.collocations()
# Out:
# wanna chat; PART JOIN; MODE #14-19teens; JOIN PART; PART PART;
# cute.-ass MP3; MP3 player; JOIN JOIN; times .. .; ACTION watches; guys
# wanna; song lasts; last night; ACTION sits; -...)...- S.M.R.; Lime
# Player; Player 12%; dont know; lez gurls; long time

# %% [markdown]
# **Question 15:** Create a frequency diagram for the **Wall Street Journal** text.

# %%
# Provide your solution here
fdist1 = FreqDist(text7)
print(fdist1)

# %% [markdown]
# **Question 16:** Create a dispersion plot diagram for the word **Whale** using the Moby Dick text.

# %%
# Provide your solution here
text1.dispersion_plot(["whale"])

# %% [markdown]
# **Question 17:** Create a dispersion plot diagram using the words **JOIN**, **chat** and **Player** using the chat corpus.

# %%
# Provide your solution here
text5.dispersion_plot(['JOIN', 'chat','Player'])

# %% [markdown]
# **Question 18:** Print the longest words of the Moby Dick text.
#
# For example the words that have more than 16 characters length.

# %%
# Provide your solution here
for word in text1:
  if len(word)>16:
    print(word)
# Out:
# uncomfortableness
# cannibalistically
# circumnavigations
# superstitiousness
# superstitiousness
# comprehensiveness
# preternaturalness
# indispensableness
# characteristically
# comprehensiveness
# comprehensiveness
# uncompromisedness
# uninterpenetratingly
# subterraneousness

# %% [markdown]
# # **Part 2: Creating an NLP pipeline**

# %% [markdown]
# **Question 1.1:** The first NLP pipeline step is to create the sentence tokenizer.
#
# * Use the following text to extract a list of sentences using the **sent_tokenize** method.

# %%
import nltk
nltk.download('punkt') # Install Punkt corpus (required by the sent_tokenize)

text = """Athens is the capital and largest city of Greece. It dominates the Attica region and is one of the world's oldest cities, with its recorded history spanning over 3,400 years. Classical Athens was a powerful city-state. """

# Provide your solution here
# Pipeline step 1: Sentence tokenizer
from nltk.tokenize import sent_tokenize
sentences = nltk.sent_tokenize(text)
sentences
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ['Athens is the capital and largest city of Greece.',
#  "It dominates the Attica region and is one of the world's oldest cities, with its recorded history spanning over 3,400 years.",
#  'Classical Athens was a powerful city-state.']

# %% [markdown]
# **Question 1.2:** How many sentences are in the text?

# %%
# Provide your solution here
len(sentences)
# Out:
# 3

# %% [markdown]
# **Question 2:** The second NLP pipeline step is to create the word tokens for each sentence.
#
# * Use the the **word_tokenize** method to extract the words (tokens) of the first sentence (Athens is the capital and largest city of Greece.).

# %%
# Provide your solution here
# Pipeline step 2: Word tokenizer

import nltk
from nltk.tokenize import word_tokenize

# Download necessary NLTK data
nltk.download('punkt')

# Define the sentence
sentence1 = "Athens is the capital and largest city of Greece."

# Tokenize the sentence into words
tokens = word_tokenize(sentence1)

# Print the tokens
print(tokens)
# Out:
# ['Athens', 'is', 'the', 'capital', 'and', 'largest', 'city', 'of', 'Greece', '.']
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# **Question 3:** Let's examine the part of speech for the first sentence.
# Print the **pos_tag** for each word (token).

# %%
# Provide your solution here
# Pipeline step 3: POS
pos = nltk.pos_tag(tokens)
pos
# Out:
# [('Athens', 'NNS'),
#  ('is', 'VBZ'),
#  ('the', 'DT'),
#  ('capital', 'NN'),
#  ('and', 'CC'),
#  ('largest', 'JJS'),
#  ('city', 'NN'),
#  ('of', 'IN'),
#  ('Greece', 'NNP'),
#  ('.', '.')]

# %% [markdown]
# **Question 4.1:** Use the **PorterStemmer** library to print the stemming of the first sentece.
#
# Examine the results? Do we have any words with the same root?

# %%
# Provide your solution here
# Pipeline step 4: Stemming

from nltk.stem import PorterStemmer

ps = PorterStemmer()

for w in word_tokenize(sentences[0]):
    rootWord=ps.stem(w)
    print(rootWord)
# Out:
# athen
# is
# the
# capit
# and
# largest
# citi
# of
# greec
# .

# %% [markdown]
# **Question 4.2:** The next, creates a dictionary of the lemmings of our text.
# * This means that we can use a unique root key to count the occurencies of the words that have the same root, e.g. key **call** for **calling**, **called**, **calls** etc.
#
# Study and run the following.

# %%
# Provide your solution here
# Pipeline step 4: Stemming

from nltk.stem import PorterStemmer

ps = PorterStemmer()
word_freq = dict()

atext = "Calls: call when called!"

for w in word_tokenize(atext):
    rootWord=ps.stem(w)

    # Create an empty dictionary

    if rootWord not in word_freq:
            word_freq[rootWord] = 1
    else:
            word_freq[rootWord] += 1
print(word_freq)
# Out:
# {'call': 3, ':': 1, 'when': 1, '!': 1}

# %% [markdown]
# **Question 4.3:** Use the WordNetLemmatizer and print the lemmas of the first sentence. Study and run the following.

# %%
# Pipeline step 4: Lematization

import nltk
nltk.download('wordnet')

from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

for token in  word_tokenize(sentences[0]):
  print(lemmatizer.lemmatize(token))
# Out:
# Athens
# is
# the
# capital
# and
# largest
# city
# of
# Greece
# .
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# >Stemming just removes or stems the last few characters of a word, often leading to incorrect meanings and spelling. Lemmatization considers the context and converts the word to its meaningful base form, which is called Lemma. Sometimes, the same word can have multiple different Lemmas.
#
# > We should identify the Part of Speech (POS) tag for the word in that specific context. Here are the examples to illustrate all the differences and use cases:
#
# > If you lemmatize the word 'Caring', it would return 'Care'. If you stem, it would return 'Car' and this is erroneous.
# If you lemmatize the word 'Stripes' in verb context, it would return 'Strip'. If you lemmatize it in noun context, it would return 'Stripe'. If you just stem it, it would just return 'Strip'.
#
# > You would get same results whether you lemmatize or stem words such as walking, running, swimming... to walk, run, swim etc.
# Lemmatization is computationally expensive since it involves look-up tables and what not. If you have large dataset and performance is an issue, go with Stemming. Remember you can also add your own rules to Stemming. If accuracy is paramount and dataset isn't humongous, go with Lemmatization.

# %% [markdown]
# **Question 4.4:** Try the following example, here we can use the lemmatize of a word using a pos e.g. an **a**djective.
#
# Study and run the following.

# %%
# import these modules
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

print(lemmatizer.lemmatize("cities"))
print(lemmatizer.lemmatize("largest", pos ="a"))
# Out:
# city
# large

# %% [markdown]
# **Question 5:** Remove the stop words from the first sentence and store the words into a new list called **filtered_sentence**.

# %%
# Step 5: Stop words removal

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

stop_words = set(stopwords.words('english'))

filtered_sentence = []

for w in tokens_sentence1:
    if w not in stop_words:
        filtered_sentence.append(w)

print(tokens_sentence1)
print(filtered_sentence)
# Out:
# ['Athens', 'is', 'the', 'capital', 'and', 'largest', 'city', 'of', 'Greece', '.']
# ['Athens', 'capital', 'largest', 'city', 'Greece', '.']

# %% [markdown]
# **Question 6:** The sixth step of the NLP Pipeline is the dependency parsing. Let's use Spacy to create a new dependency parsing plot.
#
# Study and run the following.

# %%
# Step 6: Dependency parsing

import spacy
from spacy import displacy

nlp = spacy.load("en_core_web_sm")
doc = nlp(sentence1)
displacy.render(doc, style="dep", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="89c98b17c4864520805441614a784e15-0" class="displacy" width="1625" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Athens</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
# ...

# %% [markdown]
# **Question 7:** The seventh step of the NLP Pipeline is the NER model. Let's use Spacy to explore the NER entities of the second sentence (of the initial text).
#
# Study and run the following.

# %%
# 7. NER

doc = nlp(sentences[1])
colors = {"ORG": "linear-gradient(90deg, #aa9cfc, #fc9ce7)"}
options = {"ents": ["ORG"], "colors": colors}
displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">It dominates the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Attica
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  region and is one of the world's oldest cities, with its recorded history spanning over
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3,400 years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .</div></span>

# %% [markdown]
# **Question 8:** Let's use the WordNet and explore the synonyms of the word **train**.
#
# Study and run the following.

# %%
import nltk
from nltk.corpus import wordnet as wn
nltk.download('wordnet')
syns = wn.synsets("train")
syns
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [Synset('train.n.01'),
#  Synset('string.n.04'),
#  Synset('caravan.n.01'),
#  Synset('train.n.04'),
#  Synset('train.n.05'),
#  Synset('gearing.n.01'),
#  Synset('train.v.01'),
#  Synset('train.v.02'),
#  Synset('discipline.v.01'),
#  Synset('prepare.v.05'),
#  Synset('educate.v.03'),
#  Synset('aim.v.01'),
#  Synset('coach.v.01'),
#  Synset('train.v.08'),
#  Synset('train.v.09'),
#  Synset('train.v.10'),
#  Synset('trail.v.05')]

# %% [markdown]
# **Question 9:** Explore the definition of the word **train** using the WordNet lexicon.
#
# Study and run the following.
# * syns[0] refers to 'train.n.01'

# %%
print(syns[0].definition())
# Out:
# public transport provided by a line of railway cars coupled together and drawn by a locomotive

# %% [markdown]
# **Question 10:** Let's explore an example of the **train.n.01**.

# %%
wn.synset('train.n.01').examples()
# Out:
# ["express trains don't stop at Princeton Junction"]

# %% [markdown]
# **Question 11:** Let's extract hyponyms of the **train.n.01**.

# %%
wn.synset('train.n.01').hyponyms()
# Out:
# [Synset('mail_train.n.01'),
#  Synset('boat_train.n.01'),
#  Synset('streamliner.n.01'),
#  Synset('subway_train.n.01'),
#  Synset('freight_train.n.01'),
#  Synset('passenger_train.n.01'),
#  Synset('hospital_train.n.01'),
#  Synset('car_train.n.01')]

# %% [markdown]
# **Question 12:** Study and run the following chunking script.

# %%
# Chunking

text = "The litle white ball fall in the lake"


sentence=nltk.pos_tag(word_tokenize(text))
# NP: Noun phrase
# DT	determiner
# JJ	adjective
# NN	noun, singular

grammar = "NP: {<DT>?<JJ>*<NN>}"
cp = nltk.RegexpParser(grammar)
result = cp.parse(sentence)
print(result)
# Out:
# (S
#   (NP The/DT litle/JJ white/JJ ball/NN)
#   (NP fall/NN)
#   in/IN
#   (NP the/DT lake/NN))

# %% [markdown]
# **Question 13:** The next script creates a word cloud for a given text.
# Run the following script.

# %%
import sys

# !{sys.executable} -m pip install wordcloud


text = """
London is the capital and largest city of England and the United Kingdom.[8][9] The city stands on the River Thames in the south-east of England, at the head of its 50-mile (80 km) estuary leading to the North Sea. London has been a major settlement for two millennia. Londinium was founded by the Romans.[10] The City of London, London's ancient core and financial centre − an area of just 1.12 square miles (2.9 km2) and colloquially known as the Square Mile − retains boundaries that closely follow its medieval limits.[11][12][13][14][15][note 1] The adjacent City of Westminster is an Inner London borough and has for centuries been the location of much of the national government. Thirty one additional boroughs north and south of the river also comprise modern London. London is governed by the mayor of London and the London Assembly.[16][note 2][17]
"""

from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt

wordcloud = WordCloud(stopwords=STOPWORDS, background_color='white',  max_words=300).generate(text)

plt.clf()
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %% [markdown]
# **Question 14:** The next scripts demostrate the use of spacy to extract information from text such as the lemmas, POS, etc.
#
# Study and run the next scripts.

# %%
import spacy

nlp = spacy.load("en_core_web_sm")

text = "The rain in Spain falls mainly on the plain."
doc = nlp(text)

for token in doc:
    print(token.text, token.lemma_, token.pos_, token.is_stop)
# Out:
# The the DET True
# rain rain NOUN False
# in in ADP True
# Spain Spain PROPN False
# falls fall VERB False
# mainly mainly ADV False
# on on ADP True
# the the DET True
# plain plain NOUN False
# . . PUNCT False

# %% [markdown]
# **Question 15:** Let's transform this to a dataframe.

# %%
import pandas as pd

cols = ("text", "lemma", "POS", "explain", "stopword")
rows = []

for t in doc:
    row = [t.text, t.lemma_, t.pos_, spacy.explain(t.pos_), t.is_stop]
    rows.append(row)

df = pd.DataFrame(rows, columns=cols)

df
# Out:
#      text   lemma    POS      explain  stopword
# 0     The     the    DET   determiner      True
# 1    rain    rain   NOUN         noun     False
# 2      in      in    ADP   adposition      True
# 3   Spain   Spain  PROPN  proper noun     False
# 4   falls    fall   VERB         verb     False
# 5  mainly  mainly    ADV       adverb     False
# 6      on      on    ADP   adposition      True
# 7     the     the    DET   determiner      True
# 8   plain   plain   NOUN         noun     False
# 9       .       .  PUNCT  punctuation     False

# %% [markdown]
# **Question 16:** Let's extract the chuncks of a text.

# %%
text = "Steve Jobs and Steve Wozniak incorporated Apple Computer on January 3, 1977, in Cupertino, California."
doc = nlp(text)

for chunk in doc.noun_chunks:
    print(chunk.text)
# Out:
# Steve Jobs
# Steve Wozniak
# Apple Computer
# January
# Cupertino
# California
